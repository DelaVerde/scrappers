# %%
import requests

# %%
r = requests.post('http://200.53.148.113/qqg/?page_id=423', data = 
                  {"page_id":423,
                   "estado":"", 
                   "razon":"",
                   "numero":"",
                   "btnBuscar":1})

# %%
from bs4 import BeautifulSoup

# %%
soup  = BeautifulSoup(r.content)
# Out:
# /usr/local/lib/python3.4/site-packages/bs4/__init__.py:166: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# To get rid of this warning, change this:
#
#  BeautifulSoup([your markup])
#
# to this:
#
#  BeautifulSoup([your markup], "lxml")
#
#   markup_type=markup_type))

# %%
select = soup.find("select",{"class":"qqp"})

# %%
select
# Out:
# <select class="qqp" id="estado" name="estado"><option selected="selected" value="0">— Seleccionar —</option><option value="AGUASCALIENTES">AGUASCALIENTES</option><option value="BAJA CALIFORNIA">BAJA CALIFORNIA</option><option value="BAJA CALIFORNIA SUR">BAJA CALIFORNIA SUR</option><option value="CAMPECHE">CAMPECHE</option><option value="CHIAPAS">CHIAPAS</option><option value="CHIHUAHUA">CHIHUAHUA</option><option value="CIUDAD DE MEXICO">CIUDAD DE MEXICO</option><option value="COAHUILA DE ZARAGOZA">COAHUILA DE ZARAGOZA</option><option value="COLIMA">COLIMA</option><option value="DISTRITO FEDERAL">DISTRITO FEDERAL</option><option value="DURANGO">DURANGO</option><option value="GUANAJUATO">GUANAJUATO</option><option value="GUERRERO">GUERRERO</option><option value="HIDALGO">HIDALGO</option><option value="JALISCO">JALISCO</option><option value="MEXICO">MEXICO</option><option value="MICHOACAN DE OCAMPO">MICHOACAN DE OCAMPO</option><option value="MORELIA">MORELIA</option><option value="MORELOS">MORELOS</option><option value="NAYARIT">NAYARIT</option><option value="NUEVO LEON">NUEVO LEON</option><option value="OAXACA DE JUAREZ">OAXACA DE JUAREZ</option><option value="PUEBLA">PUEBLA</option><option value="QUERETARO DE ARTEAGA">QUERETARO DE ARTEAGA</option><option value="QUINTANA ROO">QUINTANA ROO</option><option value="SAN LUIS POTOSI">SAN LUIS POTOSI</option><option value="SINALOA">SINALOA</option><option value="SONORA">SONORA</option><option value="TABASCO">TABASCO</option><option value="TAMAULIPAS">TAMAULIPAS</option><option value="TLAXCALA">TLAXCALA</option><option value="VERACRUZ">VERACRUZ</option><option value="VERACRUZ DE IGNACIO DE LA LLAVE">VERACRUZ DE IGNACIO DE LA LLAVE</option><option value="YUCATAN">YUCATAN</option><option value="ZACATECAS">ZACATECAS</option></select>

# %%
state_values = []
for option in select.findAll("option"):
    state_values.append(option["value"])

# %% [raw]
# state_values

# %%
state_values.remove('0')

# %%
table = soup.find("div", {"class":"table-responsive"})

# %%
table_list = []
for row in table.findAll("tr"):
    lista_row = []
    for value in table.findAll("td"):
        lista_row.append(value.text)
    table_list.append(lista_row)

# %%
table_list[0]
# Out:
# ['MEXICO',
#  ' HUIXQUILUCAN',
#  'SERVIGAS DEL VALLE, S.A. DE C.V.',
#  ' 2016-11-30',
#  ' 0',
#  '  0',
#  '  0',
#  '  0',
#  '  0',
#  '  0',
#  '  0',
#  '  0',
#  'SE NEGÓ A SER VERIFICADO',
#  'MEXICO',
#  ' TEOLOYUCAN',
#  'SATELITE GAS, S.A. DE C.V.',
#  ' 2016-11-30',
#  ' 0',
#  '  0',
#  '  0',
#  '  0',
#  '  0',
#  '  0',
#  '  3',
#  '  0',
#  'SIN INFRACCIÓN',
#  'MEXICO',
#  ' TEOLOYUCAN',
#  'AZTECA GAS, S.A. DE C.V.',
#  ' 2016-11-30',
#  ' 38',
#  '  0',
#  '  0',
#  '  0',
#  '  0',
#  '  0',
#  '  0',
#  '  0',
#  'SIN INFRACCIÓN',
#  'MEXICO',
#  ' TLALNEPANTLA',
#  'GASOMATICO, S.A. DE C.V.',
#  ' 2016-11-30',
#  ' 0',
#  '  0',
#  '  0',
#  '  0',
#  '  0',
#  '  0',
#  '  0',
#  '  0',
#  'SE NEGÓ A SER VERIFICADO',
#  'MEXICO',
#  ' TLALNEPANTLA',
#  'UNIGAS, S.A. DE C.V.',
#  ' 2016-11-30',
#  ' 0',
#  '  0',
#  '  0',
#  '  0',
#  '  0',
#  '  0',
#  '  0',
#  '  0',
#  'SIN INFRACCIÓN',
#  'MEXICO',
#  ' TLALNEPANTLA',
#  'GAS Y SERVICIO, S.A. DE C.V.',
#  ' 2016-11-30',
#  ' 0',
#  '  0',
#  '  0',
#  '  0',
#  '  0',
#  '  0',
#  '  0',
#  '  0',
#  'SE NEGÓ A SER VERIFICADO',
#  'MEXICO',
#  ' TLALNEPANTLA',
#  'GAS METROPOLITANO, S.A. DE C.V.',
#  ' 2016-11-30',
#  ' 0',
#  '  0',
#  '  0',
#  '  0',
#  '  0',
#  '  0',
#  '  2',
#  '  0',
#  'SIN INFRACCIÓN',
#  'HIDALGO',
#  ' MINERAL DE LA REFORMA',
#  'GAS DE HIDALGO, S.A. DE C.V.',
#  ' 2016-11-29',
#  ' 16',
#  '  0',
#  '  0',
#  '  0',
#  '  2',
#  '  0',
#  '  2',
#  '  0',
#  'SIN INFRACCIÓN',
#  'JALISCO',
#  ' TLAJOMULCO DE ZUÑIGA',
#  'THERMOGAS, S.A. DE C.V.',
#  ' 2016-11-29',
#  ' 3',
#  '  0',
#  '  0',
#  '  0',
#  '  1',
#  '  0',
#  '  0',
#  '  0',
#  'SIN INFRACCIÓN',
#  'MEXICO',
#  ' ECATEPEC',
#  'GAS NARVARTE, S.A. DE C.V.',
#  ' 2016-11-29',
#  ' 0',
#  '  0',
#  '  0',
#  '  0',
#  '  0',
#  '  0',
#  '  2',
#  '  0',
#  'SIN INFRACCIÓN',
#  'MEXICO',
#  ' ECATEPEC',
#  'FLAMA GAS, S.A. DE C.V.',
#  ' 2016-11-29',
#  ' 75',
#  '  0',
#  '  0',
#  '  0',
#  '  0',
#  '  0',
#  '  2',
#  '  0',
#  'SIN INFRACCIÓN',
#  'MEXICO',
#  ' ECATEPEC DE MORELOS',
#  'REGIO GAS, S.A. DE C.V.',
#  ' 2016-11-29',
#  ' 39',
#  '  0',
#  '  0',
#  '  0',
#  '  2',
#  '  1',
#  '  3',
#  '  0',
#  'CON INFRACCIÓN',
#  'MEXICO',
#  ' NEZAHUALCOYOTL',
#  'REGIO GAS, S.A. DE C.V.',
#  ' 2016-11-29',
#  ' 0',
#  '  0',
#  '  1',
#  '  0',
#  '  0',
#  '  0',
#  '  0',
#  '  0',
#  'SIN INFRACCIÓN',
#  'MEXICO',
#  ' NEZAHUALCOYOTL',
#  'REGIO GAS, S.A. DE C.V.',
#  ' 2016-11-29',
#  ' 0',
#  '  0',
#  '  1',
#  '  0',
#  '  0',
#  '  0',
#  '  0',
#  '  0',
#  'SIN INFRACCIÓN',
#  'CIUDAD DE MEXICO',
#  ' IZTACALCO',
#  'FLAMAMEX, S.A. DE C.V.',
#  ' 2016-11-28',
#  ' 0',
#  '  0',
#  '  1',
#  '  0',
#  '  0',
#  '  0',
#  '  0',
#  '  0',
#  'SIN INFRACCIÓN',
#  'HIDALGO',
#  ' PACHUCA DE SOTO',
#  'GARZA GAS DE PROVINCIA, S.A. DE C.V.',
#  ' 2016-11-28',
#  ' 0',
#  '  0',
#  '  0',
#  '  0',
#  '  0',
#  '  0',
#  '  0',
#  '  0',
#  'SE NEGÓ A SER VERIFICADO',
#  'HIDALGO',
#  ' PACHUCA DE SOTO',
#  'GARZA GAS DE PROVINCIA, S.A. DE C.V.',
#  ' 2016-11-28',
#  ' 0',
#  '  0',
#  '  1',
#  '  0',
#  '  0',
#  '  0',
#  '  0',
#  '  0',
#  'SIN INFRACCIÓN',
#  'HIDALGO',
#  ' PACHUCA DE SOTO',
#  'GASAMEX, S.A. DE C.V.',
#  ' 2016-11-28',
#  ' 0',
#  '  0',
#  '  1',
#  '  0',
#  '  0',
#  '  0',
#  '  0',
#  '  0',
#  'SE NEGÓ A SER VERIFICADO',
#  'JALISCO',
#  ' AHUALULCO DE MERCADO',
#  'GAS LICUADO, S.A. DE C.V.',
#  ' 2016-11-28',
#  ' 4',
#  '  0',
#  '  0',
#  '  0',
#  '  0',
#  '  0',
#  '  0',
#  '  0',
#  'SIN INFRACCIÓN',
#  'JALISCO',
#  ' AMECAMECA',
#  'GAS DE AMECA, S.A. DE C.V.',
#  ' 2016-11-28',
#  ' 0',
#  '  0',
#  '  0',
#  '  0',
#  '  0',
#  '  0',
#  '  0',
#  '  0',
#  'SE NEGÓ A SER VERIFICADO',
#  'JALISCO',
#  ' EL SALTO',
#  'MILENIUM ASOCIACION, S.A. DE C.V.',
#  ' 2016-11-28',
#  ' 0',
#  '  0',
#  '  1',
#  '  0',
#  '  0',
#  '  0',
#  '  0',
#  '  0',
#  'SIN INFRACCIÓN',
#  'JALISCO',
#  ' EL SALTO',
#  'DIESGAS, S.A. DE C.V.',
#  ' 2016-11-28',
#  ' 0',
#  '  0',
#  '  1',
#  '  0',
#  '  0',
#  '  0',
#  '  0',
#  '  0',
#  'SIN INFRACCIÓN',
#  'JALISCO',
#  ' TALA',
#  'MAMEME GAS, S.A. DE C.V.',
#  ' 2016-11-28',
#  ' 15',
#  '  0',
#  '  0',
#  '  0',
#  '  0',
#  '  0',
#  '  0',
#  '  0',
#  'SIN INFRACCIÓN',
#  'MEXICO',
#  ' ECATEPEC',
#  'GASAMEX, S.A. DE C.V.',
#  ' 2016-11-28',
#  ' 39',
#  '  0',
#  '  0',
#  '  0',
#  '  1',
#  '  0',
#  '  2',
#  '  0',
#  'SIN INFRACCIÓN',
#  'MEXICO',
#  ' ECATEPEC',
#  'SERVICIOS ESPECIALES DE GAS L.P., S.A. DE C.V.',
#  ' 2016-11-28',
#  ' 24',
#  '  0',
#  '  0',
#  '  0',
#  '  1',
#  '  1',
#  '  1',
#  '  0',
#  'CON INFRACCIÓN',
#  'MEXICO',
#  ' ECATEPEC',
#  'TRENDI CARBURACION, S.A. DE C.V.',
#  ' 2016-11-28',
#  ' 0',
#  '  0',
#  '  0',
#  '  0',
#  '  0',
#  '  0',
#  '  1',
#  '  0',
#  'SIN INFRACCIÓN',
#  'PUEBLA',
#  ' HUEJOTZINGO',
#  'EXTRA GAS, S.A. DE C.V.',
#  ' 2016-11-28',
#  ' 20',
#  '  0',
#  '  0',
#  '  0',
#  '  3',
#  '  0',
#  '  3',
#  '  0',
#  'SIN INFRACCIÓN',
#  'PUEBLA',
#  ' HUEJOTZINGO',
#  'GAS SOLIDO, S.A. DE C.V.',
#  ' 2016-11-28',
#  ' 10',
#  '  0',
#  '  0',
#  '  0',
#  '  1',
#  '  0',
#  '  1',
#  '  0',
#  'SIN INFRACCIÓN',
#  'PUEBLA',
#  ' HUEJOTZINGO',
#  'GAS EL PAISANO, S.A. DE C.V.',
#  ' 2016-11-28',
#  ' 0',
#  '  0',
#  '  0',
#  '  0',
#  '  0',
#  '  0',
#  '  1',
#  '  0',
#  'SIN INFRACCIÓN',
#  'PUEBLA',
#  ' SAN MARTIN TEXMELUCAN',
#  'EXTRA GAS, S.A. DE C.V.',
#  ' 2016-11-28',
#  ' 0',
#  '  0',
#  '  1',
#  '  1',
#  '  0',
#  '  0',
#  '  0',
#  '  0',
#  'CON INFRACCIÓN',
#  'JALISCO',
#  ' EL SALTO',
#  'SONIGAS, S.A. DE C.V.',
#  ' 2016-11-26',
#  ' 25',
#  '  9',
#  '  0',
#  '  0',
#  '  2',
#  '  1',
#  '  0',
#  '  0',
#  'CON INFRACCIÓN',
#  'JALISCO',
#  ' EL SALTO',
#  'DIESGAS, S.A. DE C.V.',
#  ' 2016-11-26',
#  ' 18',
#  '  0',
#  '  0',
#  '  0',
#  '  0',
#  '  0',
#  '  0',
#  '  0',
#  'SIN INFRACCIÓN',
#  'JALISCO',
#  ' TLAJOMULCO DE ZUÑIGA',
#  'DIESGAS, S.A. DE C.V.',
#  ' 2016-11-26',
#  ' 0',
#  '  0',
#  '  1',
#  '  0',
#  '  0',
#  '  0',
#  '  0',
#  '  0',
#  'SIN INFRACCIÓN',
#  'CIUDAD DE MEXICO',
#  ' IZTAPALAPA',
#  'GASAMEX, S.A. DE C.V.',
#  ' 2016-11-25',
#  ' 0',
#  '  0',
#  '  1',
#  '  0',
#  '  0',
#  '  0',
#  '  0',
#  '  0',
#  'SIN INFRACCIÓN',
#  'HIDALGO',
#  ' TEPEJI DEL RIO DE OCAMPO',
#  'REDEGAS, S.A. DE C.V.',
#  ' 2016-11-25',
#  ' 0',
#  '  0',
#  '  0',
#  '  0',
#  '  0',
#  '  0',
#  '  0',
#  '  0',
#  'SE NEGÓ A SER VERIFICADO',
#  'HIDALGO',
#  ' TEPEJI DEL RIO DE OCAMPO',
#  'GAS TOMZA DE MEXICO, S.A. DE C.V.',
#  ' 2016-11-25',
#  ' 0',
#  '  0',
#  '  0',
#  '  0',
#  '  0',
#  '  0',
#  '  1',
#  '  0',
#  'SIN INFRACCIÓN',
#  'JALISCO',
#  ' GUADALAJARA',
#  'MULTIGAS, S.A. DE C.V.',
#  ' 2016-11-25',
#  ' 0',
#  '  0',
#  '  1',
#  '  0',
#  '  0',
#  '  0',
#  '  0',
#  '  0',
#  'SIN INFRACCIÓN',
#  'JALISCO',
#  ' ZAPOPAN',
#  'VELA GAS OCCIDENTE, S. DE R.L. DE C.V.',
#  ' 2016-11-25',
#  ' 0',
#  '  0',
#  '  0',
#  '  0',
#  '  0',
#  '  0',
#  '  0',
#  '  0',
#  'SE NEGÓ A SER VERIFICADO',
#  'CIUDAD DE MEXICO',
#  ' BENITO JUAREZ',
#  'GASOMATICO, S.A. DE C.V.',
#  ' 2016-11-24',
#  ' 0',
#  '  0',
#  '  1',
#  '  0',
#  '  0',
#  '  0',
#  '  0',
#  '  0',
#  'SE NEGÓ A SER VERIFICADO',
#  'CIUDAD DE MEXICO',
#  ' BENITO JUAREZ',
#  'GASOMATICO, S.A. DE C.V.',
#  ' 2016-11-24',
#  ' 0',
#  '  0',
#  '  1',
#  '  0',
#  '  0',
#  '  0',
#  '  0',
#  '  0',
#  'SE NEGÓ A SER VERIFICADO',
#  'CIUDAD DE MEXICO',
#  ' MIGUEL HIDALGO',
#  'REGIO GAS, S.A. DE C.V.',
#  ' 2016-11-24',
#  ' 44',
#  '  0',
#  '  0',
#  '  0',
#  '  2',
#  '  1',
#  '  2',
#  '  0',
#  'CON INFRACCIÓN',
#  'HIDALGO',
#  ' PACHUCA DE SOTO',
#  'GARZA GAS DE PROVINCIA, S.A. DE C.V.',
#  ' 2016-11-24',
#  ' 15',
#  '  0',
#  '  0',
#  '  0',
#  '  2',
#  '  0',
#  '  0',
#  '  0',
#  'SIN INFRACCIÓN',
#  'JALISCO',
#  ' GUADALAJARA',
#  'MULTIGAS, S.A. DE C.V.',
#  ' 2016-11-24',
#  ' 4',
#  '  0',
#  '  0',
#  '  0',
#  '  0',
#  '  0',
#  '  0',
#  '  0',
#  'SIN INFRACCIÓN',
#  'JALISCO',
#  ' ZAPOTLANEJO',
#  'GAS BUTEP, S.A.',
#  ' 2016-11-24',
#  ' 0',
#  '  0',
#  '  0',
#  '  0',
#  '  0',
#  '  0',
#  '  0',
#  '  0',
#  'SE NEGÓ A SER VERIFICADO',
#  'QUERETARO DE ARTEAGA',
#  ' CORREGIDORA',
#  'GAS EXPRESS NIETO, S.A. DE C.V.',
#  ' 2016-11-24',
#  ' 13',
#  '  0',
#  '  0',
#  '  0',
#  '  3',
#  '  0',
#  '  2',
#  '  0',
#  'SIN INFRACCIÓN',
#  'QUERETARO DE ARTEAGA',
#  ' SAN JUAN DEL RIO',
#  'GAS EXPRESS NIETO, S.A. DE C.V.',
#  ' 2016-11-24',
#  ' 13',
#  '  0',
#  '  0',
#  '  0',
#  '  0',
#  '  0',
#  '  0',
#  '  0',
#  'SIN INFRACCIÓN',
#  'CIUDAD DE MEXICO',
#  ' GUSTAVO A. MADERO',
#  'FLAMAMEX, S.A. DE C.V.',
#  ' 2016-11-23',
#  ' 68',
#  '  0',
#  '  0',
#  '  0',
#  '  2',
#  '  1',
#  '  2',
#  '  0',
#  'CON INFRACCIÓN',
#  'CIUDAD DE MEXICO',
#  ' GUSTAVO A. MADERO',
#  'USA GAS SAN JUAN, S.A. DE C.V.',
#  ' 2016-11-23',
#  ' 19',
#  '  0',
#  '  0',
#  '  0',
#  '  1',
#  '  0',
#  '  0',
#  '  0',
#  'SIN INFRACCIÓN',
#  'JALISCO',
#  ' TEOCALTICHE',
#  'ALFA GAS, S.A. DE C.V.',
#  ' 2016-11-23',
#  ' 5',
#  '  0',
#  '  0',
#  '  0',
#  '  0',
#  '  0',
#  '  0',
#  '  0',
#  'SIN INFRACCIÓN',
#  'QUERETARO DE ARTEAGA',
#  ' COLON',
#  'GAS EXPRESS NIETO, S.A. DE C.V.',
#  ' 2016-11-23',
#  ' 8',
#  '  0',
#  '  0',
#  '  0',
#  '  0',
#  '  0',
#  '  0',
#  '  0',
#  'CON INFRACCIÓN',
#  'QUERETARO DE ARTEAGA',
#  ' QUERETARO',
#  'GAS EXPRESS NIETO, S.A. DE C.V.',
#  ' 2016-11-23',
#  ' 24',
#  '  0',
#  '  0',
#  '  0',
#  '  4',
#  '  1',
#  '  4',
#  '  0',
#  'CON INFRACCIÓN',
#  'QUERETARO DE ARTEAGA',
#  ' QUERETARO',
#  'GAS EXPRESS NIETO, S.A. DE C.V.',
#  ' 2016-11-23',
#  ' 13',
#  '  0',
#  '  0',
#  '  0',
#  '  0',
#  '  0',
#  '  0',
#  '  0',
#  'SIN INFRACCIÓN',
#  'QUERETARO DE ARTEAGA',
#  ' QUERETARO',
#  'GAS EXPRESS NIETO, S.A. DE C.V.',
#  ' 2016-11-23',
#  ' 0',
#  '  0',
#  '  1',
#  '  0',
#  '  0',
#  '  0',
#  '  0',
#  '  0',
#  'SIN INFRACCIÓN',
#  'CIUDAD DE MEXICO',
#  ' ALVARO OBREGON',
#  'GAS LICUADO DE MEXICO, S.A. DE C.V.',
#  ' 2016-11-22',
#  ' 0',
#  '  0',
#  '  0',
#  '  0',
#  '  0',
#  '  0',
#  '  1',
#  '  0',
#  'SIN INFRACCIÓN',
#  'CIUDAD DE MEXICO',
#  ' AZCAPOTZALCO',
#  'COMPAÑIA DE GAS DEL CENTRO, S.A. DE C.V.',
#  ' 2016-11-22',
#  ' 12',
#  '  0',
#  '  0',
#  '  0',
#  '  0',
#  '  0',
#  '  2',
#  '  0',
#  'SIN INFRACCIÓN',
#  'CIUDAD DE MEXICO',
#  ' CUAUHTEMOC',
#  'REGIO GAS, S.A. DE C.V.',
#  ' 2016-11-22',
#  ' 0',
#  '  0',
#  '  1',
#  '  0',
#  '  0',
#  '  0',
#  '  0',
#  '  0',
#  'SIN INFRACCIÓN',
#  'CIUDAD DE MEXICO',
#  ' CUAUHTEMOC',
#  'GASOMATICO, S.A. DE C.V.',
#  ' 2016-11-22',
#  ' 0',
#  '  0',
#  '  1',
#  '  0',
#  '  0',
#  '  0',
#  '  0',
#  '  0',
#  'SE NEGÓ A SER VERIFICADO',
#  'CIUDAD DE MEXICO',
#  ' VENUSTIANO CARRANZA',
#  'GASOMATICO, S.A. DE C.V.',
#  ' 2016-11-22',
#  ' 0',
#  '  0',
#  '  1',
#  '  0',
#  '  0',
#  '  0',
#  '  0',
#  '  0',
#  'SE NEGÓ A SER VERIFICADO',
#  'GUANAJUATO',
#  ' IRAPUATO',
#  'GAS EXPRESS NIETO, S.A. DE C.V.',
#  ' 2016-11-22',
#  ' 13',
#  '  0',
#  '  0',
#  '  0',
#  '  3',
#  '  3',
#  '  3',
#  '  0',
#  'CON INFRACCIÓN',
#  'GUANAJUATO',
#  ' LEON',
#  'DOS MIL GAS, S.A. DE C.V.',
#  ' 2016-11-22',
#  ' 24',
#  '  1',
#  '  0',
#  '  0',
#  '  4',
#  '  0',
#  '  0',
#  '  0',
#  'CON INFRACCIÓN',
#  'GUANAJUATO',
#  ' LEON',
#  'DISTRIBUIDORA DE GAS NOEL, S.A. DE C.V.',
#  ' 2016-11-22',
#  ' 9',
#  '  0',
#  '  0',
#  '  0',
#  '  0',
#  '  0',
#  '  0',
#  '  0',
#  'SIN INFRACCIÓN',
#  'GUANAJUATO',
#  ' PENJAMO',
#  'DURAGAS, S.A. DE C.V.',
#  ' 2016-11-22',
#  ' 11',
#  '  0',
#  '  0',
#  '  0',
#  '  0',
#  '  0',
#  '  1',
#  '  0',
#  'SIN INFRACCIÓN',
#  'GUANAJUATO',
#  ' PENJAMO',
#  'DURAGAS, S.A. DE C.V.',
#  ' 2016-11-22',
#  ' 0',
#  '  0',
#  '  1',
#  '  0',
#  '  0',
#  '  0',
#  '  0',
#  '  0',
#  'SIN INFRACCIÓN',
#  'GUANAJUATO',
#  ' PENJAMO',
#  'DISTRIBUIDORA DE GAS NOEL, S.A. DE C.V.',
#  ' 2016-11-22',
#  ' 0',
#  '  0',
#  '  1',
#  '  0',
#  '  0',
#  '  0',
#  '  0',
#  '  0',
#  'SIN INFRACCIÓN',
#  'GUANAJUATO',
#  ' SALAMANCA',
#  'DISTRIBUIDORA MEXICANA DE GAS L.P., S.A. DE C.V.',
#  ' 2016-11-22',
#  ' 0',
#  '  0',
#  '  0',
#  '  0',
#  '  0',
#  '  0',
#  '  0',
#  '  0',
#  'SE NEGÓ A SER VERIFICADO',
#  'SAN LUIS POTOSI',
#  ' GUADALCAZAR',
#  'JEBLA, S.A. DE C.V.',
#  ' 2016-11-22',
#  ' 0',
#  '  0',
#  '  0',
#  '  0',
#  '  0',
#  '  0',
#  '  2',
#  '  0',
#  'SIN INFRACCIÓN',
#  'JALISCO',
#  ' HUEJUCAR',
#  'COMBUSTIBLES Y GASES DE ZACATECAS, S.A. DE C.V.',
#  ' 2016-11-21',
#  ' 5',
#  '  0',
#  '  0',
#  '  0',
#  '  0',
#  '  0',
#  '  0',
#  '  0',
#  'CON INFRACCIÓN',
#  'CIUDAD DE MEXICO',
#  ' MIGUEL HIDALGO',
#  'REGIO GAS, S.A. DE C.V.',
#  ' 2016-11-18',
#  ' 0',
#  '  0',
#  '  1',
#  '  0',
#  '  0',
#  '  0',
#  '  0',
#  '  0',
#  'SIN INFRACCIÓN',
#  'CIUDAD DE MEXICO',
#  ' MIGUEL HIDALGO',
#  'REGIO GAS, S.A. DE C.V.',
#  ' 2016-11-18',
#  ' 0',
#  '  0',
#  '  1',
#  '  1',
#  '  0',
#  '  0',
#  '  0',
#  '  0',
#  'CON INFRACCIÓN',
#  'MEXICO',
#  ' CUAUTITLAN IZCALLI',
#  'GARZA GAS, S.A. DE C.V.',
#  ' 2016-11-18',
#  ' 0',
#  '  0',
#  '  0',
#  '  0',
#  '  0',
#  '  0',
#  '  3',
#  '  0',
#  'SIN INFRACCIÓN',
#  'MEXICO',
#  ' CUAUTITLAN IZCALLI',
#  'SUPERGAS DE MEXICO, S.A. DE C.V.',
#  ' 2016-11-18',
#  ' 12',
#  '  0',
#  '  0',
#  '  0',
#  '  0',
#  '  0',
#  '  0',
#  '  0',
#  'SIN INFRACCIÓN',
#  'MEXICO',
#  ' HUIXQUILUCAN',
#  'SERVIGAS DEL VALLE, S.A. DE C.V.',
#  ' 2016-11-18',
#  ' 30',
#  '  0',
#  '  0',
#  '  0',
#  '  0',
#  '  0',
#  '  0',
#  '  0',
#  'SIN INFRACCIÓN',
#  'MEXICO',
#  ' NICOLAS ROMERO',
#  'VIDRIOGAS, S.A. DE C.V.',
#  ' 2016-11-18',
#  ' 21',
#  '  0',
#  '  0',
#  '  0',
#  '  1',
#  '  0',
#  '  0',
#  '  0',
#  'CON INFRACCIÓN',
#  'MEXICO',
#  ' NICOLAS ROMERO',
#  'GAS EXPRESS NIETO DE MEXICO, S.A. DE C.V.',
#  ' 2016-11-18',
#  ' 18',
#  '  0',
#  '  0',
#  '  0',
#  '  0',
#  '  0',
#  '  0',
#  '  0',
#  'SIN INFRACCIÓN',
#  'MEXICO',
#  ' TENANGO DEL VALLE',
#  'GAS DEL VALLE DE TOLLOCAN, S.A. DE C.V.',
#  ' 2016-11-18',
#  ' 5',
#  '  0',
#  '  0',
#  '  0',
#  '  1',
#  '  0',
#  '  0',
#  '  0',
#  'SIN INFRACCIÓN',
#  'MEXICO',
#  ' TEOLOYUCAN',
#  'SATELITE GAS, S.A. DE C.V.',
#  ' 2016-11-18',
#  ' 0',
#  '  0',
#  '  0',
#  '  0',
#  '  0',
#  '  0',
#  '  4',
#  '  0',
#  'SIN INFRACCIÓN',
#  'MEXICO',
#  ' TEOLOYUCAN',
#  'THEO GAS, S.A. DE C.V.',
#  ' 2016-11-18',
#  ' 4',
#  '  0',
#  '  0',
#  '  0',
#  '  0',
#  '  0',
#  '  0',
#  '  0',
#  ...]

# %%
def state_data(state):
    headers_data = {'Pragma':'no-cache',
                                    'Origin':'http://200.53.148.113',
                                    'Accept-Encoding':'gzip,deflate',
                                    'Accept-Language':'es-ES,es;q=0.8,en;q=0.6',
                                    'Upgrade-Insecure-Requests':'1',
                                    'User-Agent':'Mozilla/5.0(Macintosh;IntelMacOSX10_12_3)AppleWebKit/537.36(KHTML,likeGecko)Chrome/55.0.2883.95Safari/537.36',
                                    'Content-Type':'application/x-www-form-urlencoded',
                                    'Accept':'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8',
                                    'Cache-Control':'no-cache',
                                    'Referer':'http://200.53.148.113/qqg/?page_id=423',
                                    'Cookie':'gsScrollPos=;_ga=GA1.1.1696495404.1483817531;_gali=btnBuscaGas',
                                    'Connection':'keep-alive'}
    r = requests.post('http://200.53.148.113/qqg/?page_id=423', 
                      data ='page_id=423&estado='+state+'&municipio=&razon=&btnBuscaGas=1', 
                      headers = headers_data)
    soup = BeautifulSoup(r.content)
    table = soup.find("div", {"class":"table-responsive"})
    return table

# %%
o = state_data("NUEVO LEON")

# %%
o.findAll("tr")[2].findAll("td")
# Out:
# [<td>NUEVO LEON</td>,
#  <td> LAMPAZOS DE NARANJO</td>,
#  <td>GAS SANTOS, S.A. DE C.V.</td>,
#  <td> 2016-11-07</td>,
#  <td> 0</td>,
#  <td>  0</td>,
#  <td>  0</td>,
#  <td>  0</td>,
#  <td>  0</td>,
#  <td>  0</td>,
#  <td>  0</td>,
#  <td>  0</td>,
#  <td>SE NEGÓ A SER VERIFICADO</td>]

# %%
def extract_header(table):
    header_row = []
    header_html = table.find("thead")
    for row in header_html.find("tr").findAll("th"):
        header_row.append(row.text)
    return header_row

# %%
full_table = []
count = 0
for state in state_values:
    print(state)
    table = state_data(state)
    for row in table.findAll("tr"):
        row_data = []
        for value in row.findAll("td"):
            row_data.append(value.text)
        if len(row_data)> 0:
            if len(row_data)>13:
                row_data[1] = str(row_data[1]) + " "+ str(row_data[2]) 
                row_data.pop(2)  #Algunas rows tienen errores en el nombre. Eliminamos los nombres de más. Esperando poderlo limpiar.
            full_table = full_table+[row_data]
    if count == len(state_values)-1:
        header = [extract_header(table)]
        full_table = header + full_table
    count = count +1
# Out:
# AGUASCALIENTES
# BAJA CALIFORNIA
# BAJA CALIFORNIA SUR
# CAMPECHE
# CHIAPAS
# CHIHUAHUA
# CIUDAD DE MEXICO
# COAHUILA DE ZARAGOZA
# COLIMA
# DISTRITO FEDERAL
# DURANGO
# GUANAJUATO
# GUERRERO
# HIDALGO
# JALISCO
# MEXICO
# MICHOACAN DE OCAMPO
# MORELIA
# MORELOS
# NAYARIT
# NUEVO LEON
# OAXACA DE JUAREZ
# PUEBLA
# QUERETARO DE ARTEAGA
# QUINTANA ROO
# SAN LUIS POTOSI
# SINALOA
# SONORA
# TABASCO
# TAMAULIPAS
# TLAXCALA
# VERACRUZ
# VERACRUZ DE IGNACIO DE LA LLAVE
# YUCATAN
# ZACATECAS

# %%
full_table[0:30]
# Out:
# [['Estado',
#   ' Municipio',
#   ' Razón social',
#   ' Fecha',
#   ' BV',
#   ' BI',
#   ' VVPV',
#   ' VVPI',
#   ' VPV',
#   ' VPI',
#   ' AV',
#   ' AI',
#   ' Resultado'],
#  ['AGUASCALIENTES',
#   ' AGUASCALIENTES',
#   'SONIGAS, S.A. DE C.V.',
#   ' 2016-08-11',
#   ' 10',
#   '  0',
#   '  0',
#   '  0',
#   '  0',
#   '  0',
#   '  3',
#   '  0',
#   'SIN INFRACCIÓN'],
#  ['AGUASCALIENTES',
#   ' AGUASCALIENTES',
#   'GAS EXPRESS NIETO, S.A. DE C.V.',
#   ' 2016-08-11',
#   ' 9',
#   '  0',
#   '  0',
#   '  0',
#   '  0',
#   '  0',
#   '  1',
#   '  0',
#   'SIN INFRACCIÓN'],
#  ['AGUASCALIENTES',
#   ' EL LLANO',
#   'GAS TITANIUM, S.A. DE C.V.',
#   ' 2016-08-11',
#   ' 0',
#   '  0',
#   '  0',
#   '  0',
#   '  0',
#   '  0',
#   '  1',
#   '  0',
#   'SIN INFRACCIÓN'],
#  ['AGUASCALIENTES',
#   ' AGUASCALIENTES',
#   'DISTRIBUIDORA DE GAS SAN MARCOS, S.A. DE C.V.',
#   ' 2016-08-10',
#   ' 0',
#   '  0',
#   '  0',
#   '  0',
#   '  0',
#   '  0',
#   '  0',
#   '  0',
#   'NEGATIVA DE VERIFICACIÓN'],
#  ['AGUASCALIENTES',
#   ' AGUASCALIENTES',
#   'PETROQUIMICA BAJIO, S.A. DE C.V.',
#   ' 2016-08-10',
#   ' 6',
#   '  0',
#   '  0',
#   '  0',
#   '  0',
#   '  0',
#   '  0',
#   '  0',
#   'SIN INFRACCIÓN'],
#  ['AGUASCALIENTES',
#   ' AGUASCALIENTES',
#   'DISTRIBUIDORA DE GAS NOEL, S.A. DE C.V.',
#   ' 2016-08-10',
#   ' 18',
#   '  0',
#   '  0',
#   '  0',
#   '  1',
#   '  0',
#   '  1',
#   '  0',
#   'SIN INFRACCIÓN'],
#  ['AGUASCALIENTES',
#   ' SAN FRANCISCO DE LOS ROMO',
#   'DISTRIBUIDORA DE GAS NOEL, S.A. DE C.V.',
#   ' 2016-08-10',
#   ' 0',
#   '  0',
#   '  1',
#   '  0',
#   '  0',
#   '  0',
#   '  0',
#   '  0',
#   'SIN INFRACCIÓN'],
#  ['AGUASCALIENTES',
#   ' AGUASCALIENTES',
#   'DURAGAS, S.A. DE C.V.',
#   ' 2016-08-09',
#   ' 0',
#   '  0',
#   '  1',
#   '  0',
#   '  0',
#   '  0',
#   '  0',
#   '  0',
#   'NEGATIVA DE VERIFICACIÓN'],
#  ['AGUASCALIENTES',
#   ' AGUASCALIENTES',
#   'CORPORATIVO VAN E GAS, S.A. DE C.V.',
#   ' 2016-08-09',
#   ' 6',
#   '  0',
#   '  0',
#   '  0',
#   '  0',
#   '  0',
#   '  0',
#   '  0',
#   'SIN INFRACCIÓN'],
#  ['AGUASCALIENTES',
#   ' CALVILLO',
#   'DISTRIBUIDORA DE GAS NOEL, S.A. DE C.V.',
#   ' 2016-08-09',
#   ' 5',
#   '  0',
#   '  0',
#   '  0',
#   '  2',
#   '  0',
#   '  3',
#   '  0',
#   'CON INFRACCIÓN'],
#  ['AGUASCALIENTES',
#   ' AGUASCALIENTES',
#   'GAS EXPRESS NIETO, S.A. DE C.V.',
#   ' 2016-04-22',
#   ' 0',
#   '  0',
#   '  0',
#   '  0',
#   '  0',
#   '  0',
#   '  0',
#   '  0',
#   'SIN INFRACCIÓN'],
#  ['AGUASCALIENTES',
#   ' AGUASCALIENTES',
#   'SONIGAS, S.A. DE C.V.',
#   ' 2016-04-22',
#   ' 0',
#   '  0',
#   '  0',
#   '  0',
#   '  0',
#   '  0',
#   '  2',
#   '  0',
#   'SIN INFRACCIÓN'],
#  ['AGUASCALIENTES',
#   ' AGUASCALIENTES',
#   'DURAGAS, S.A. DE C.V.',
#   ' 2016-04-21',
#   ' 0',
#   '  0',
#   '  0',
#   '  0',
#   '  6',
#   '  0',
#   '  6',
#   '  0',
#   'CON INFRACCIÓN'],
#  ['AGUASCALIENTES',
#   ' SAN FRANCISCO DE LOS ROMO',
#   'DISTRIBUIDORA DE GAS NOEL, S.A. DE C.V.',
#   ' 2016-04-21',
#   ' 0',
#   '  0',
#   '  0',
#   '  0',
#   '  0',
#   '  0',
#   '  0',
#   '  0',
#   'SIN INFRACCIÓN'],
#  ['AGUASCALIENTES',
#   ' AGUASCALIENTES',
#   'COMERCIALIZADORA DE GAS DEL BAJIO, S.A. DE C.V.',
#   ' 2016-04-20',
#   ' 0',
#   '  0',
#   '  0',
#   '  0',
#   '  0',
#   '  0',
#   '  0',
#   '  0',
#   'SIN INFRACCIÓN'],
#  ['AGUASCALIENTES',
#   ' AGUASCALIENTES',
#   'CENTRAL DE GAS, S.A. DE C.V.',
#   ' 2016-04-20',
#   ' 0',
#   '  0',
#   '  0',
#   '  0',
#   '  2',
#   '  1',
#   '  4',
#   '  0',
#   'CON INFRACCIÓN'],
#  ['AGUASCALIENTES',
#   ' JESUS MARIA',
#   'DISTRIBUIDORA DE GAS JIMENEZ, S.A. DE C.V.',
#   ' 2016-04-19',
#   ' 0',
#   '  0',
#   '  0',
#   '  0',
#   '  0',
#   '  0',
#   '  2',
#   '  1',
#   'CON INFRACCIÓN'],
#  ['AGUASCALIENTES',
#   ' PABELLON DE ARTEAGA',
#   'DURAGAS, S.A. DE C.V.',
#   ' 2016-04-19',
#   ' 0',
#   '  0',
#   '  0',
#   '  0',
#   '  0',
#   '  0',
#   '  0',
#   '  0',
#   'SIN INFRACCIÓN'],
#  ['BAJA CALIFORNIA',
#   ' MEXICALI',
#   'GAS SILZA, S.A. DE C.V.',
#   ' 2016-10-12',
#   ' 7',
#   '  0',
#   '  0',
#   '  0',
#   '  0',
#   '  0',
#   '  0',
#   '  0',
#   'SIN INFRACCIÓN'],
#  ['BAJA CALIFORNIA',
#   ' MEXICALI',
#   'KINO GAS DEL NOROESTE, S.A. DE C.V.',
#   ' 2016-10-12',
#   ' 16',
#   '  0',
#   '  0',
#   '  0',
#   '  0',
#   '  0',
#   '  0',
#   '  0',
#   'CON INFRACCIÓN'],
#  ['BAJA CALIFORNIA',
#   ' MEXICALI',
#   'GAS BUTANO PROPANO DE BAJA CALIFORNIA, S.A. DE C.V.',
#   ' 2016-10-12',
#   ' 0',
#   '  0',
#   '  0',
#   '  0',
#   '  0',
#   '  0',
#   '  1',
#   '  0',
#   'SIN INFRACCIÓN'],
#  ['BAJA CALIFORNIA',
#   ' ENSENADA',
#   'GENERADORES DE ENERGIA DEL NOROESTE, S.A. DE C.V.',
#   ' 2016-10-11',
#   ' 8',
#   '  0',
#   '  0',
#   '  0',
#   '  3',
#   '  1',
#   '  2',
#   '  0',
#   'CON INFRACCIÓN'],
#  ['BAJA CALIFORNIA',
#   ' TIJUANA',
#   'GENERADORES DE ENERGIA DEL NOROESTE, S.A. DE C.V.',
#   ' 2016-10-11',
#   ' 20',
#   '  0',
#   '  0',
#   '  0',
#   '  1',
#   '  0',
#   '  1',
#   '  0',
#   'SIN INFRACCIÓN'],
#  ['BAJA CALIFORNIA',
#   ' TIJUANA',
#   'KINO GAS DE TIJUANA, S.A. DE C.V.',
#   ' 2016-10-11',
#   ' 0',
#   '  0',
#   '  0',
#   '  0',
#   '  0',
#   '  0',
#   '  0',
#   '  0',
#   'SIN INFRACCIÓN'],
#  ['BAJA CALIFORNIA',
#   ' ENSENADA',
#   'COMPAÑIA DE GAS DE ENSENADA, S.A. DE C.V.',
#   ' 2016-10-10',
#   ' 0',
#   '  0',
#   '  0',
#   '  0',
#   '  3',
#   '  0',
#   '  3',
#   '  0',
#   'SIN INFRACCIÓN'],
#  ['BAJA CALIFORNIA',
#   ' ENSENADA',
#   'GAS SILZA, S.A. DE C.V.',
#   ' 2016-10-10',
#   ' 6',
#   '  0',
#   '  0',
#   '  0',
#   '  0',
#   '  0',
#   '  0',
#   '  0',
#   'CON INFRACCIÓN'],
#  ['BAJA CALIFORNIA',
#   ' ENSENADA',
#   'COMPAÑIA DE GAS DE ENSENADA, S.A. DE C.V.',
#   ' 2016-10-10',
#   ' 7',
#   '  0',
#   '  0',
#   '  0',
#   '  1',
#   '  0',
#   '  1',
#   '  0',
#   'SIN INFRACCIÓN'],
#  ['BAJA CALIFORNIA',
#   ' MEXICALI',
#   'HIDROCARBUROS DEL NOROESTE, S.A. DE C.V.',
#   ' 2016-04-12',
#   ' 0',
#   '  0',
#   '  0',
#   '  0',
#   '  0',
#   '  0',
#   '  0',
#   '  0',
#   'NEGATIVA'],
#  ['BAJA CALIFORNIA',
#   ' MEXICALI',
#   'GAS SILZA, S.A. DE C.V.',
#   ' 2016-04-12',
#   ' 24',
#   '  0',
#   '  0',
#   '  0',
#   '  0',
#   '  0',
#   '  0',
#   '  0',
#   'SIN INFRACCIÓN']]

# %%
import csv
len(full_table)
with open("sample_data/reportegaseras.csv", "w") as f:
    writer = csv.writer(f)
    writer.writerows(full_table)

# %%
import pandas as pd

# %%
pd.read_csv("sample_data/reportegaseras.csv")
# Out:
#                Estado                      Municipio  \
# 0      AGUASCALIENTES                 AGUASCALIENTES
# 1      AGUASCALIENTES                 AGUASCALIENTES
# 2      AGUASCALIENTES                       EL LLANO
# 3      AGUASCALIENTES                 AGUASCALIENTES
# 4      AGUASCALIENTES                 AGUASCALIENTES
# 5      AGUASCALIENTES                 AGUASCALIENTES
# 6      AGUASCALIENTES      SAN FRANCISCO DE LOS ROMO
# 7      AGUASCALIENTES                 AGUASCALIENTES
# 8      AGUASCALIENTES                 AGUASCALIENTES
# 9      AGUASCALIENTES                       CALVILLO
# 10     AGUASCALIENTES                 AGUASCALIENTES
# 11     AGUASCALIENTES                 AGUASCALIENTES
# 12     AGUASCALIENTES                 AGUASCALIENTES
# 13     AGUASCALIENTES      SAN FRANCISCO DE LOS ROMO
# 14     AGUASCALIENTES                 AGUASCALIENTES
# 15     AGUASCALIENTES                 AGUASCALIENTES
# 16     AGUASCALIENTES                    JESUS MARIA
# 17     AGUASCALIENTES            PABELLON DE ARTEAGA
# 1369              GAS BUTANO DE GUADALUPE, S.A. DE C.V.   2016-03-14   12
# 1370      DISTRIBUIDORA DE GAS SAN MARCOS, S.A. DE C.V.   2016-03-14    0
#
#        BI   VVPV   VVPI   VPV   VPI   AV   AI                 Resultado
# 0       0      0      0     0     0    3    0            SIN INFRACCIÓN
# 1       0      0      0     0     0    1    0            SIN INFRACCIÓN
# 2       0      0      0     0     0    1    0            SIN INFRACCIÓN
# 3       0      0      0     0     0    0    0  NEGATIVA DE VERIFICACIÓN
# 4       0      0      0     0     0    0    0            SIN INFRACCIÓN
# 5       0      0      0     1     0    1    0            SIN INFRACCIÓN
# 6       0      1      0     0     0    0    0            SIN INFRACCIÓN
# 7       0      1      0     0     0    0    0  NEGATIVA DE VERIFICACIÓN
# 8       0      0      0     0     0    0    0            SIN INFRACCIÓN
# 9       0      0      0     2     0    3    0            CON INFRACCIÓN
# 10      0      0      0     0     0    0    0            SIN INFRACCIÓN
# 11      0      0      0     0     0    2    0            SIN INFRACCIÓN
# 12      0      0      0     6     0    6    0            CON INFRACCIÓN
# 13      0      0      0     0     0    0    0            SIN INFRACCIÓN
# 14      0      0      0     0     0    0    0            SIN INFRACCIÓN
# 15      0      0      0     2     1    4    0            CON INFRACCIÓN
# 16      0      0      0     0     0    2    1            CON INFRACCIÓN
# 17      0      0      0     0     0    0    0            SIN INFRACCIÓN
# 18      0      0      0     0     0    0    0            SIN INFRACCIÓN
# 19      0      0      0     0     0    0    0            CON INFRACCIÓN
# 20      0      0      0     0     0    1    0            SIN INFRACCIÓN
# 21      0      0      0     3     1    2    0            CON INFRACCIÓN
# 22      0      0      0     1     0    1    0            SIN INFRACCIÓN
# 23      0      0      0     0     0    0    0            SIN INFRACCIÓN
# 24      0      0      0     3     0    3    0            SIN INFRACCIÓN
# 25      0      0      0     0     0    0    0            CON INFRACCIÓN
# 26      0      0      0     1     0    1    0            SIN INFRACCIÓN
# 27      0      0      0     0     0    0    0                  NEGATIVA
# 28      0      0      0     0     0    0    0            SIN INFRACCIÓN
# 29      0      0      0     0     0    0    0            SIN INFRACCIÓN
# ...   ...    ...    ...   ...   ...  ...  ...                       ...
# 1341    0      0      0     0     0    1    0            SIN INFRACCIÓN
# 1342    0      0      0     1     0    1    0            SIN INFRACCIÓN
# 1343    0      0      0     0     0    0    0            SIN INFRACCIÓN
# 1344    0      0      0     0     0    0    0  SE NEGÓ A SER VERIFICADO
# 1345    0      0      0     0     0    0    0            SIN INFRACCIÓN
# 1346    0      1      0     0     0    0    0            SIN INFRACCIÓN
# 1347    0      1      0     0     0    0    0            SIN INFRACCIÓN
# 1348    0      1      0     0     0    0    0            SIN INFRACCIÓN
# 1349    0      1      0     0     0    0    0            SIN INFRACCIÓN
# 1350    0      0      0     1     1    1    0            CON INFRACCIÓN
# 1351    0      0      0     0     0    0    0  NEGATIVA DE VERIFICACIÓN
# 1352    0      0      0     1     1    0    0            CON INFRACCIÓN
# 1353    0      0      0     0     0    0    0            SIN INFRACCIÓN
# 1354    0      0      0     0     0    1    0            SIN INFRACCIÓN
# 1355    0      0      0     0     0    2    0            SIN INFRACCIÓN
# 1356    0      0      0     0     0    2    0            SIN INFRACCIÓN
# 1357    0      0      0     1     1    0    0            CON INFRACCIÓN
# 1358    0      0      0     0     0    0    0            SIN INFRACCIÓN
# 1359    0      0      0     0     0    0    0            SIN INFRACCIÓN
# 1360    0      0      0     0     0    1    0            SIN INFRACCIÓN
# 1361    0      0      0     0     0    0    0            SIN INFRACCIÓN
# 1362    0      0      0     1     1    0    0            CON INFRACCIÓN
# 1363    0      0      0     1     0    0    0            SIN INFRACCIÓN
# 1364    0      0      0     1     1    0    0            CON INFRACCIÓN
# 1365    0      0      0     0     0    0    0            SIN INFRACCIÓN
# 1366    0      1      0     0     0    0    0            SIN INFRACCIÓN
# 1367    0      1      0     0     0    0    0            SIN INFRACCIÓN
# 1368    0      1      0     0     0    0    0            SIN INFRACCIÓN
# 1369    0      0      0     0     0    0    0            SIN INFRACCIÓN
# 1370    0      0      0     0     0    0    0                  NEGATIVA
#
# [1371 rows x 13 columns]
